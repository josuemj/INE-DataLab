# %%
import pandas as pd
data = pd.read_excel("fallecidos2013-2023.xlsx")
data
# Out:
#         año fall_les tipo_veh modelo_veh  g_modelo_veh marca color  \
# 0      2013        2        1          5      ignorado     5     2
# 1      2013        2        1          5      ignorado     5     2
# 2      2013        2        1          5      ignorado     5     2
# 3      2013        1        4          5      ignorado    24     1
# 4      2013        2        4          5      ignorado    24     1
# ...     ...      ...      ...        ...           ...   ...   ...
# 99510  2020        2        4       9999            99     2     5
# 99511  2020        2        4       9999            99     2     5
# 99512  2020        2        4       9999            99     2     5
# 99513  2020        1        4       2019             5   168     1
# 99514  2020        2        4       2013             5    27     1
#
#       hora_ocu_fall g_hora_fall g_hora_5_fall día_sem_ocu_fall mes_ocu_fall  \
# 0                 5           1      ignorado                2            1
# ...

# %%
import pandas as pd

# Diccionario de transformación
fall_les_dict = {
    1: "Fallecido",
    2: "Lesionado",
    3: "Ignorado"
}

# Asegurarse de que los valores sean numéricos si vienen como string
data["fall_les"] = pd.to_numeric(data["fall_les"], errors="coerce")

# Aplicar la transformación
data["fall_les"] = data["fall_les"].map(fall_les_dict)

# Mostrar los primeros resultados
data.head()
# Out:
#     año   fall_les tipo_veh modelo_veh  g_modelo_veh marca color  \
# 0  2013  Lesionado        1          5      ignorado     5     2
# 1  2013  Lesionado        1          5      ignorado     5     2
# 2  2013  Lesionado        1          5      ignorado     5     2
# 3  2013  Fallecido        4          5      ignorado    24     1
# 4  2013  Lesionado        4          5      ignorado    24     1
#
#   hora_ocu_fall g_hora_fall g_hora_5_fall día_sem_ocu_fall mes_ocu_fall  \
# 0             5           1      ignorado                2            1
# 1             5           1      ignorado                2            1
# 2             5           1      ignorado                2            1
# 3             0           1      ignorado                2            1
# 4             0           1      ignorado                2            1
#
#   causa_acc
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2

# %%
tipo_veh_dict = {
    1: "Automóvil",
    2: "Camioneta sport o blazer",
    3: "Pick up",
    4: "Motocicleta",
    5: "Camión",
    6: "Cabezal",
    7: "Bus extraurbano",
    8: "Jeep",
    9: "Microbús",
    10: "Taxi",
    11: "Panel",
    12: "Bus urbano",
    13: "Tractor",
    14: "Moto taxi",
    15: "Furgón",
    16: "Grúa",
    17: "Bus escolar",
    18: "Bicicleta",
    19: "Avioneta",
    20: "Montacargas",
    21: "Bus militar",
    22: "Cuatrimoto",
    23: "Furgoneta",
    24: "Motos acuáticas",
    99: "Ignorado"
}

# Intentar convertir a número y transformar solo si es válido
data["tipo_veh_num"] = pd.to_numeric(data["tipo_veh"], errors="coerce")
data.loc[data["tipo_veh_num"].notna(), "tipo_veh"] = data["tipo_veh_num"].map(tipo_veh_dict)

# Eliminar la columna auxiliar
data.drop(columns="tipo_veh_num", inplace=True)

data
# Out:
#         año   fall_les     tipo_veh modelo_veh  g_modelo_veh marca color  \
# 0      2013  Lesionado    Automóvil          5      ignorado     5     2
# 1      2013  Lesionado    Automóvil          5      ignorado     5     2
# 2      2013  Lesionado    Automóvil          5      ignorado     5     2
# 3      2013  Fallecido  Motocicleta          5      ignorado    24     1
# 4      2013  Lesionado  Motocicleta          5      ignorado    24     1
# ...     ...        ...          ...        ...           ...   ...   ...
# 99510  2020  Lesionado  Motocicleta       9999            99     2     5
# 99511  2020  Lesionado  Motocicleta       9999            99     2     5
# 99512  2020  Lesionado  Motocicleta       9999            99     2     5
# 99513  2020  Fallecido  Motocicleta       2019             5   168     1
# 99514  2020  Lesionado  Motocicleta       2013             5    27     1
#
#       hora_ocu_fall g_hora_fall g_hora_5_fall día_sem_ocu_fall mes_ocu_fall  \
# ...

# %%
modelo_veh_dict = {
    1: '1970-1979',
    2: '1980-1989',
    3: '1990-1999',
    4: '2000-2009',
    5: '2010-2019',
    6: '2020-2029',
    99: 'Ignorado',
    999: 'Ignorado',
    9999: 'Ignorado',
}

# Intentar convertir a número y guardar en una columna temporal
data["modelo_veh_num"] = pd.to_numeric(data["modelo_veh"], errors="coerce")

# Aplicar transformación solo si el valor está en el diccionario
def transformar_modelo(original, num):
    if pd.notna(num) and int(num) in modelo_veh_dict:
        return modelo_veh_dict[int(num)]
    return original

data["modelo_veh"] = data.apply(
    lambda row: transformar_modelo(row["modelo_veh"], row["modelo_veh_num"]),
    axis=1
)

# Eliminar columna auxiliar
data.drop(columns="modelo_veh_num", inplace=True)

data
# Out:
#         año   fall_les     tipo_veh modelo_veh  g_modelo_veh marca color  \
# 0      2013  Lesionado    Automóvil  2010-2019      ignorado     5     2
# 1      2013  Lesionado    Automóvil  2010-2019      ignorado     5     2
# 2      2013  Lesionado    Automóvil  2010-2019      ignorado     5     2
# 3      2013  Fallecido  Motocicleta  2010-2019      ignorado    24     1
# 4      2013  Lesionado  Motocicleta  2010-2019      ignorado    24     1
# ...     ...        ...          ...        ...           ...   ...   ...
# 99510  2020  Lesionado  Motocicleta   Ignorado            99     2     5
# 99511  2020  Lesionado  Motocicleta   Ignorado            99     2     5
# 99512  2020  Lesionado  Motocicleta   Ignorado            99     2     5
# 99513  2020  Fallecido  Motocicleta       2019             5   168     1
# 99514  2020  Lesionado  Motocicleta       2013             5    27     1
#
#       hora_ocu_fall g_hora_fall g_hora_5_fall día_sem_ocu_fall mes_ocu_fall  \
# ...

# %%
g_modelo_veh_dict = {
    1: '1970-1979',
    2: '1980-1989',
    3: '1990-1999',
    4: '2000-2009',
    5: '2010-2019',
    6: '2020-2029',
    99: 'Ignorado',
    9999: 'Ignorado'
}

# Intentar convertir a número y guardar en una columna temporal
data["g_modelo_veh_num"] = pd.to_numeric(data[" g_modelo_veh"], errors="coerce")

# Aplicar transformación solo si el valor está en el diccionario
def transformar_modelo(original, num):
    if pd.notna(num) and int(num) in g_modelo_veh_dict:
        return g_modelo_veh_dict[int(num)]
    return original

data[" g_modelo_veh"] = data.apply(
    lambda row: transformar_modelo(row[" g_modelo_veh"], row["g_modelo_veh_num"]),
    axis=1
)

# Eliminar columna auxiliar
data.drop(columns="g_modelo_veh_num", inplace=True)

data
# Out:
#         año   fall_les     tipo_veh modelo_veh  g_modelo_veh marca color  \
# 0      2013  Lesionado    Automóvil  2010-2019      ignorado     5     2
# 1      2013  Lesionado    Automóvil  2010-2019      ignorado     5     2
# 2      2013  Lesionado    Automóvil  2010-2019      ignorado     5     2
# 3      2013  Fallecido  Motocicleta  2010-2019      ignorado    24     1
# 4      2013  Lesionado  Motocicleta  2010-2019      ignorado    24     1
# ...     ...        ...          ...        ...           ...   ...   ...
# 99510  2020  Lesionado  Motocicleta   Ignorado      Ignorado     2     5
# 99511  2020  Lesionado  Motocicleta   Ignorado      Ignorado     2     5
# 99512  2020  Lesionado  Motocicleta   Ignorado      Ignorado     2     5
# 99513  2020  Fallecido  Motocicleta       2019     2010-2019   168     1
# 99514  2020  Lesionado  Motocicleta       2013     2010-2019    27     1
#
#       hora_ocu_fall g_hora_fall g_hora_5_fall día_sem_ocu_fall mes_ocu_fall  \
# ...

# %%
marcas_dict = {
    1: "AHM", 2: "TVS Apache", 3: "Asia Hero", 4: "Audi", 5: "Avanti", 6: "Bajaj", 7: "Blue Bird", 8: "BMW",
    9: "Changan", 10: "Chevrolet", 11: "Chrysler", 12: "Daewoo", 13: "Daihatsu", 14: "Datsun", 15: "Dodge",
    16: "Fiat", 17: "Ford", 18: "Freedom", 19: "Freightliner", 20: "Genesis", 21: "Geo", 22: "Alfa Romeo",
    23: "GMC", 24: "Great Wall", 25: "Hero Hunk", 26: "Hino", 27: "Honda", 28: "Hyundai", 29: "Infiniti",
    30: "Internacional", 31: "Isuzu", 32: "Italika", 33: "Jaguar", 34: "Jeep", 35: "Jialing", 36: "John Deere",
    37: "Jumbo", 38: "Kawasaki", 39: "Keeway", 40: "Kenworth", 41: "Kia", 42: "Kinlon", 43: "Kymco",
    44: "Land Rover", 45: "Loncin", 46: "Mahindra", 47: "Lexus", 48: "Mazda", 49: "MCI", 50: "Mercedes Benz",
    51: "Mini Cooper", 52: "Mitsubishi", 53: "Motolansa", 54: "Movesa", 55: "Porche", 56: "Nissan",
    57: "Peter Bilt", 58: "Peugeot", 59: "Piaggio", 60: "Plymouth", 61: "Renault", 62: "Rhino", 63: "Sanyang",
    64: "Serpento", 65: "Soprano", 66: "Subaru", 67: "Suzuki", 68: "Sym", 69: "Toyota", 70: "Cadillac",
    71: "Harley Davidson", 72: "United Motors (UM)", 73: "Volkswagen", 74: "Volvo", 75: "Wuling", 76: "Yamaha",
    77: "Yumbo dakar", 78: "Ferrari", 79: "Seat", 80: "Autoriksha", 81: "Eagle flight", 83: "Honlei",
    84: "Jac", 85: "Jinbei", 86: "Hummer", 87: "X-bow KRM", 88: "Mack", 89: "Pontiac", 90: "Scion",
    91: "ZX auto", 92: "Sterling", 93: "Yiben", 94: "Ritchie Bros", 95: "Chery Destiny", 96: "Vento",
    97: "Citroen", 98: "Dayun", 99: "JMC", 100: "Haojue", 101: "Hyosung", 102: "Jincheng", 103: "Lifan",
    104: "Macat", 105: "Pegasus", 106: "Rolls Royse", 107: "Acura", 108: "Kingo", 109: "Raybar", 110: "Regent",
    111: "Sing", 112: "Shineray", 113: "Skigo", 114: "Tough", 115: "Wuyang", 116: "Caterpillar", 117: "Opel",
    118: "Scrambler", 119: "Mercury", 120: "Saturn Corporation", 121: "BYD", 122: "Lincoln", 123: "Shimano",
    124: "Vecesa", 125: "Dayang", 126: "Dinamo", 127: "DPV Dover", 128: "FAW Jiabao", 129: "Fisher",
    130: "Frontier", 131: "Makiba", 132: "Motinsa", 133: "Kinroad", 134: "Qingqi", 135: "Transmetro",
    136: "Wanfeng", 137: "Cadisa", 138: "Ssangyong", 139: "Daelim", 140: "Bashan", 141: "Zongshen",
    142: "Sukida", 143: "Chongqing", 144: "Foton", 145: "Chana", 146: "Prymouth", 147: "Aprilia",
    148: "Fastran", 149: "Skoda", 150: "Mustang", 151: "Geely", 152: "Daifo", 153: "Workman",
    154: "Forward", 155: "King long", 156: "Automosa", 157: "GAC Gonow", 158: "Ud Trucks", 159: "Scania",
    160: "New Holland", 161: "Freeway", 162: "Keiko", 163: "Benelli", 164: "Jetix", 165: "TMR SL",
    166: "Ape City", 167: "Brigadier", 168: "MRT", 169: "Oldsmobile", 170: "KTM", 171: "BMX", 172: "Senke",
    173: "CF Moto", 174: "Busscar", 175: "Sinotruk", 176: "Sanlg", 177: "Jiangsu sinki", 178: "Berliet",
    179: "Aurus Senat", 180: "Fruehauf", 181: "Kioti", 182: "Maya tour", 183: "Sanya", 184: "Triumph",
    185: "Kenton", 186: "Skygo", 187: "Great Dane", 188: "Phenix", 189: "Segway", 190: "Otros", 999: "Ignorado"
}

# Intentar convertir a número y guardar en una columna temporal
data["marca_num"] = pd.to_numeric(data["marca"], errors="coerce")

# Aplicar transformación solo si el valor está en el diccionario
def transformar_modelo(original, num):
    if pd.notna(num) and int(num) in marcas_dict:
        return marcas_dict[int(num)]
    return original

data["marca"] = data.apply(
    lambda row: transformar_modelo(row["marca"], row["marca_num"]),
    axis=1
)

# Eliminar columna auxiliar
data.drop(columns="marca_num", inplace=True)

data
# Out:
#         año   fall_les     tipo_veh modelo_veh  g_modelo_veh       marca  \
# 0      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 1      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 2      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 3      2013  Fallecido  Motocicleta  2010-2019      ignorado  Great Wall
# 4      2013  Lesionado  Motocicleta  2010-2019      ignorado  Great Wall
# ...     ...        ...          ...        ...           ...         ...
# 99510  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99511  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99512  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99513  2020  Fallecido  Motocicleta       2019     2010-2019         MRT
# 99514  2020  Lesionado  Motocicleta       2013     2010-2019       Honda
#
#       color hora_ocu_fall g_hora_fall g_hora_5_fall día_sem_ocu_fall  \
# ...

# %%
color_dict = {
    1: "Rojo",
    2: "Blanco",
    3: "Azul",
    4: "Gris",
    5: "Negro",
    6: "Verde",
    7: "Amarillo",
    8: "Celeste",
    9: "Corinto",
    10: "Café",
    11: "Beige",
    12: "Turquesa",
    13: "Marfil",
    14: "Anaranjado",
    15: "Morado",
    16: "Rosado",
    17: "Varios colores",
    99: "Ignorado"
}

# Intentar convertir a número y guardar en una columna temporal
data["color_num"] = pd.to_numeric(data["color"], errors="coerce")

# Aplicar transformación solo si el valor está en el diccionario
def transformar_modelo(original, num):
    if pd.notna(num) and int(num) in color_dict:
        return color_dict[int(num)]
    return original

data["color"] = data.apply(
    lambda row: transformar_modelo(row["color"], row["color_num"]),
    axis=1
)

# Eliminar columna auxiliar
data.drop(columns="color_num", inplace=True)

data
# Out:
#         año   fall_les     tipo_veh modelo_veh  g_modelo_veh       marca  \
# 0      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 1      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 2      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 3      2013  Fallecido  Motocicleta  2010-2019      ignorado  Great Wall
# 4      2013  Lesionado  Motocicleta  2010-2019      ignorado  Great Wall
# ...     ...        ...          ...        ...           ...         ...
# 99510  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99511  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99512  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99513  2020  Fallecido  Motocicleta       2019     2010-2019         MRT
# 99514  2020  Lesionado  Motocicleta       2013     2010-2019       Honda
#
#         color hora_ocu_fall g_hora_fall g_hora_5_fall día_sem_ocu_fall  \
# ...

# %%
data["hora_ocu_fall"] = data["hora_ocu_fall"].replace(0, "Ignorado").astype(str)
data["hora_ocu_fall"] = data["hora_ocu_fall"].str.strip().replace("0", "Ignorado")
data
# Out:
#         año   fall_les     tipo_veh modelo_veh  g_modelo_veh       marca  \
# 0      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 1      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 2      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 3      2013  Fallecido  Motocicleta  2010-2019      ignorado  Great Wall
# 4      2013  Lesionado  Motocicleta  2010-2019      ignorado  Great Wall
# ...     ...        ...          ...        ...           ...         ...
# 99510  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99511  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99512  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99513  2020  Fallecido  Motocicleta       2019     2010-2019         MRT
# 99514  2020  Lesionado  Motocicleta       2013     2010-2019       Honda
#
#         color hora_ocu_fall g_hora_fall g_hora_5_fall día_sem_ocu_fall  \
# ...

# %%
g_hora_fall_dict = {
    1: "00:00 a 05:59",
    2: "06:00 a 11:59",
    3: "12:00 a 17:59",
    4: "18:00 a 23:59",
    5: "Ignorada"
}

# Intentar convertir a número y guardar en una columna temporal
data["g_hora_fall_num"] = pd.to_numeric(data["g_hora_fall"], errors="coerce")

# Aplicar transformación solo si el valor está en el diccionario
def transformar_modelo(original, num):
    if pd.notna(num) and int(num) in g_hora_fall_dict:
        return g_hora_fall_dict[int(num)]
    return original

data["g_hora_fall"] = data.apply(
    lambda row: transformar_modelo(row["g_hora_fall"], row["g_hora_fall_num"]),
    axis=1
)

# Eliminar columna auxiliar
data.drop(columns="g_hora_fall_num", inplace=True)

data
# Out:
#         año   fall_les     tipo_veh modelo_veh  g_modelo_veh       marca  \
# 0      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 1      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 2      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 3      2013  Fallecido  Motocicleta  2010-2019      ignorado  Great Wall
# 4      2013  Lesionado  Motocicleta  2010-2019      ignorado  Great Wall
# ...     ...        ...          ...        ...           ...         ...
# 99510  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99511  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99512  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99513  2020  Fallecido  Motocicleta       2019     2010-2019         MRT
# 99514  2020  Lesionado  Motocicleta       2013     2010-2019       Honda
#
#         color hora_ocu_fall    g_hora_fall g_hora_5_fall día_sem_ocu_fall  \
# ...

# %%
g_hora_5_fall_dict = {
    1: "Mañana",
    2: "Tarde",
    3: "Noche",
    4: "Ignorada"
}

# Intentar convertir a número y guardar en una columna temporal
data["g_hora_5_fall_num"] = pd.to_numeric(data["g_hora_5_fall"], errors="coerce")

# Aplicar transformación solo si el valor está en el diccionario
def transformar_modelo(original, num):
    if pd.notna(num) and int(num) in g_hora_5_fall_dict:
        return g_hora_5_fall_dict[int(num)]
    return original

data["g_hora_5_fall"] = data.apply(
    lambda row: transformar_modelo(row["g_hora_5_fall"], row["g_hora_5_fall_num"]),
    axis=1
)

# Eliminar columna auxiliar
data.drop(columns="g_hora_5_fall_num", inplace=True)

data
# Out:
#         año   fall_les     tipo_veh modelo_veh  g_modelo_veh       marca  \
# 0      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 1      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 2      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 3      2013  Fallecido  Motocicleta  2010-2019      ignorado  Great Wall
# 4      2013  Lesionado  Motocicleta  2010-2019      ignorado  Great Wall
# ...     ...        ...          ...        ...           ...         ...
# 99510  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99511  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99512  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99513  2020  Fallecido  Motocicleta       2019     2010-2019         MRT
# 99514  2020  Lesionado  Motocicleta       2013     2010-2019       Honda
#
#         color hora_ocu_fall    g_hora_fall g_hora_5_fall día_sem_ocu_fall  \
# ...

# %%
dia_sem_ocu_fall_dict = {
    1: "Lunes",
    2: "Martes",
    3: "Miércoles",
    4: "Jueves",
    5: "Viernes",
    6: "Sábado",
    7: "Domingo"
}
# Intentar convertir a número y guardar en una columna temporal
data["día_sem_ocu_fall_num"] = pd.to_numeric(data["día_sem_ocu_fall"], errors="coerce")

# Aplicar transformación solo si el valor está en el diccionario
def transformar_modelo(original, num):
    if pd.notna(num) and int(num) in dia_sem_ocu_fall_dict:
        return dia_sem_ocu_fall_dict[int(num)]
    return original

data["día_sem_ocu_fall"] = data.apply(
    lambda row: transformar_modelo(row["día_sem_ocu_fall"], row["día_sem_ocu_fall_num"]),
    axis=1
)

# Eliminar columna auxiliar
data.drop(columns="día_sem_ocu_fall_num", inplace=True)

data
# Out:
#         año   fall_les     tipo_veh modelo_veh  g_modelo_veh       marca  \
# 0      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 1      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 2      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 3      2013  Fallecido  Motocicleta  2010-2019      ignorado  Great Wall
# 4      2013  Lesionado  Motocicleta  2010-2019      ignorado  Great Wall
# ...     ...        ...          ...        ...           ...         ...
# 99510  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99511  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99512  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99513  2020  Fallecido  Motocicleta       2019     2010-2019         MRT
# 99514  2020  Lesionado  Motocicleta       2013     2010-2019       Honda
#
#         color hora_ocu_fall    g_hora_fall g_hora_5_fall día_sem_ocu_fall  \
# ...

# %%
mes_ocu_fall_dict = {
    1: "Enero",
    2: "Febrero",
    3: "Marzo",
    4: "Abril",
    5: "Mayo",
    6: "Junio",
    7: "Julio",
    8: "Agosto",
    9: "Septiembre",
    10: "Octubre",
    11: "Noviembre",
    12: "Diciembre"
}


# Intentar convertir a número y guardar en una columna temporal
data["mes_ocu_fall_num"] = pd.to_numeric(data["mes_ocu_fall"], errors="coerce")

# Aplicar transformación solo si el valor está en el diccionario
def transformar_modelo(original, num):
    if pd.notna(num) and int(num) in mes_ocu_fall_dict:
        return mes_ocu_fall_dict[int(num)]
    return original

data["mes_ocu_fall"] = data.apply(
    lambda row: transformar_modelo(row["mes_ocu_fall"], row["mes_ocu_fall_num"]),
    axis=1
)

# Eliminar columna auxiliar
data.drop(columns="mes_ocu_fall_num", inplace=True)

data
# Out:
#         año   fall_les     tipo_veh modelo_veh  g_modelo_veh       marca  \
# 0      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 1      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 2      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 3      2013  Fallecido  Motocicleta  2010-2019      ignorado  Great Wall
# 4      2013  Lesionado  Motocicleta  2010-2019      ignorado  Great Wall
# ...     ...        ...          ...        ...           ...         ...
# 99510  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99511  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99512  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99513  2020  Fallecido  Motocicleta       2019     2010-2019         MRT
# 99514  2020  Lesionado  Motocicleta       2013     2010-2019       Honda
#
#         color hora_ocu_fall    g_hora_fall g_hora_5_fall día_sem_ocu_fall  \
# ...

# %%
causa_acc_dict = {
    1: "Colisión",
    2: "Choque",
    3: "Vuelco",
    4: "Caída",
    5: "Atropello",
    6: "Derrape",
    7: "Embarranco",
    8: "Encuneto",
    99: "Ignorado"
}


# Intentar convertir a número y guardar en una columna temporal
data["causa_acc_num"] = pd.to_numeric(data["causa_acc"], errors="coerce")

# Aplicar transformación solo si el valor está en el diccionario
def transformar_modelo(original, num):
    if pd.notna(num) and int(num) in causa_acc_dict:
        return causa_acc_dict[int(num)]
    return original

data["causa_acc"] = data.apply(
    lambda row: transformar_modelo(row["causa_acc"], row["causa_acc_num"]),
    axis=1
)

# Eliminar columna auxiliar
data.drop(columns="causa_acc_num", inplace=True)

data
# Out:
#         año   fall_les     tipo_veh modelo_veh  g_modelo_veh       marca  \
# 0      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 1      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 2      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 3      2013  Fallecido  Motocicleta  2010-2019      ignorado  Great Wall
# 4      2013  Lesionado  Motocicleta  2010-2019      ignorado  Great Wall
# ...     ...        ...          ...        ...           ...         ...
# 99510  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99511  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99512  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99513  2020  Fallecido  Motocicleta       2019     2010-2019         MRT
# 99514  2020  Lesionado  Motocicleta       2013     2010-2019       Honda
#
#         color hora_ocu_fall    g_hora_fall g_hora_5_fall día_sem_ocu_fall  \
# ...

# %%
data.to_csv("Accidentes_2013_2023.csv", index=False)
data
# Out:
#         año   fall_les     tipo_veh modelo_veh  g_modelo_veh       marca  \
# 0      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 1      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 2      2013  Lesionado    Automóvil  2010-2019      ignorado      Avanti
# 3      2013  Fallecido  Motocicleta  2010-2019      ignorado  Great Wall
# 4      2013  Lesionado  Motocicleta  2010-2019      ignorado  Great Wall
# ...     ...        ...          ...        ...           ...         ...
# 99510  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99511  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99512  2020  Lesionado  Motocicleta   Ignorado      Ignorado  TVS Apache
# 99513  2020  Fallecido  Motocicleta       2019     2010-2019         MRT
# 99514  2020  Lesionado  Motocicleta       2013     2010-2019       Honda
#
#         color hora_ocu_fall    g_hora_fall g_hora_5_fall día_sem_ocu_fall  \
# ...
